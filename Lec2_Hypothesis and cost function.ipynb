# %%
import tensorflow as tf

# %%
# X and Y data
x_train = [1,2,3]
y_train = [4,6,8]

# %%
W = tf.Variable(tf.random_normal([1]), name = 'weight')
b = tf.Variable(tf.random_normal([1]), name = 'bias')

# %%
# Our hypothesis Wx + b
hypothesis = x_train*W +b

# %%
# cost / Loss function
cost = tf.reduce_mean(tf.square(hypothesis - y_train))

# %%
# Minimize , GradientDescent
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

# %%
# Launch the graph in a session
sess = tf.Session()
# Initializes global variables in the graph
sess.run(tf.global_variables_initializer())

# %%
# Fit the Line
for step in range(2001):
    sess.run(train)
    if step % 20 == 0:
        print(step, sess.run(cost), sess.run(W), sess.run(b))
# Out:
# 0 31.790232 [0.3425115] [-0.15847908]
# 20 0.4732337 [2.2940767] [0.767192]
# 40 0.1723107 [2.4586658] [0.9036122]
# 60 0.15416081 [2.4540982] [0.96261144]
# 80 0.13999008 [2.434375] [1.0120765]
# 100 0.12714109 [2.414115] [1.0585729]
# 120 0.11547174 [2.3946679] [1.1028228]
# 140 0.10487307 [2.3761213] [1.1449875]
# 160 0.09524744 [2.3584452] [1.18517]
# 180 0.086505264 [2.3415995] [1.223464]
# 200 0.078565486 [2.325546] [1.2599583]
# 220 0.07135444 [2.3102462] [1.2947375]
# 240 0.06480516 [2.2956657] [1.3278822]
# 260 0.058857184 [2.2817705] [1.3594692]
# 280 0.053455055 [2.2685282] [1.389572]
# 300 0.04854873 [2.2559085] [1.4182599]
# 320 0.0440927 [2.2438815] [1.4455996]
# 340 0.04004565 [2.2324202] [1.4716544]
# 360 0.036370154 [2.2214973] [1.4964845]
# 380 0.033031996 [2.211088] [1.5201478]
# 400 0.030000158 [2.2011673] [1.542699]
# 420 0.027246686 [2.1917133] [1.5641905]
# 440 0.02474578 [2.1827035] [1.5846719]
# 460 0.022474637 [2.1741173] [1.6041906]
# 480 0.020411776 [2.1659346] [1.6227921]
# 500 0.018538276 [2.1581361] [1.6405195]
# 520 0.016836746 [2.1507041] [1.6574138]
# 540 0.015291407 [2.1436214] [1.6735144]
# 560 0.013887919 [2.136872] [1.6888579]
# 580 0.012613217 [2.1304398] [1.7034801]
# 600 0.011455587 [2.1243098] [1.7174152]
# 620 0.010404131 [2.1184673] [1.7306956]
# 640 0.009449181 [2.1128998] [1.7433522]
# 660 0.008581885 [2.107594] [1.7554138]
# 680 0.0077942386 [2.1025376] [1.7669083]
# 700 0.007078834 [2.0977185] [1.7778629]
# 720 0.0064290836 [2.093126] [1.7883025]
# 740 0.0058390102 [2.0887496] [1.7982517]
# 760 0.005303119 [2.0845788] [1.807733]
# 780 0.0048163263 [2.0806031] [1.8167691]
# 800 0.004374238 [2.0768154] [1.8253806]
# 820 0.0039727907 [2.0732055] [1.8335869]
# 840 0.0036081078 [2.0697649] [1.841408]
# 860 0.0032769365 [2.0664861] [1.8488612]
# 880 0.0029761705 [2.0633616] [1.8559644]
# 900 0.0027030045 [2.0603838] [1.8627337]
# 920 0.002454912 [2.057546] [1.8691847]
# 940 0.0022296046 [2.0548413] [1.8753325]
# 960 0.0020249595 [2.0522642] [1.8811914]
# 980 0.0018390947 [2.049808] [1.8867748]
# 1000 0.0016702889 [2.0474672] [1.8920959]
# 1020 0.0015169928 [2.0452366] [1.8971671]
# 1040 0.0013777548 [2.0431104] [1.902]
# 1060 0.0012513098 [2.041085] [1.9066055]
# 1080 0.001136458 [2.0391533] [1.9109945]
# 1100 0.001032132 [2.0373132] [1.9151776]
# 1120 0.00093740836 [2.03556] [1.9191641]
# 1140 0.000851362 [2.0338886] [1.9229631]
# 1160 0.0007732248 [2.032296] [1.9265838]
# 1180 0.0007022502 [2.030778] [1.9300339]
# 1200 0.0006377926 [2.029332] [1.9333221]
# 1220 0.00057926815 [2.0279534] [1.9364556]
# 1240 0.00052609 [2.0266397] [1.9394418]
# 1260 0.00047780224 [2.0253878] [1.9422878]
# 1280 0.00043394868 [2.0241945] [1.945]
# 1300 0.0003941153 [2.0230575] [1.947585]
# 1320 0.0003579552 [2.0219738] [1.9500482]
# 1340 0.00032509386 [2.0209413] [1.9523958]
# 1360 0.00029525306 [2.0199566] [1.954633]
# 1380 0.0002681525 [2.019019] [1.9567652]
# 1400 0.00024354256 [2.0181253] [1.9587971]
# 1420 0.00022119404 [2.0172734] [1.9607334]
# 1440 0.00020088704 [2.0164616] [1.9625789]
# 1460 0.00018244755 [2.015688] [1.9643376]
# 1480 0.00016570785 [2.0149508] [1.9660136]
# 1500 0.000150495 [2.0142484] [1.9676107]
# 1520 0.00013668482 [2.0135784] [1.9691329]
# 1540 0.0001241346 [2.0129402] [1.9705838]
# 1560 0.00011274333 [2.012332] [1.9719663]
# 1580 0.00010239586 [2.0117526] [1.9732839]
# 1600 9.29968e-05 [2.0112002] [1.9745395]
# 1620 8.4461506e-05 [2.010674] [1.9757359]
# 1640 7.671023e-05 [2.0101721] [1.9768761]
# 1660 6.966807e-05 [2.0096943] [1.9779627]
# 1680 6.32711e-05 [2.0092385] [1.9789987]
# 1700 5.7466536e-05 [2.0088046] [1.9799854]
# 1720 5.2190706e-05 [2.0083907] [1.980926]
# 1740 4.7402e-05 [2.0079963] [1.9818225]
# 1760 4.304851e-05 [2.0076206] [1.9826769]
# 1780 3.9098395e-05 [2.0072625] [1.9834911]
# 1800 3.5511377e-05 [2.006921] [1.9842669]
# 1820 3.2252672e-05 [2.0065958] [1.9850062]
# 1840 2.9291055e-05 [2.0062857] [1.9857109]
# 1860 2.6603811e-05 [2.0059903] [1.9863824]
# 1880 2.4161374e-05 [2.005709] [1.9870224]
# 1900 2.1942067e-05 [2.0054407] [1.9876323]
# 1920 1.9929337e-05 [2.0051851] [1.9882134]
# 1940 1.8101007e-05 [2.0049415] [1.9887673]
# 1960 1.643975e-05 [2.0047092] [1.9892949]
# 1980 1.4929957e-05 [2.004488] [1.989798]
# 2000 1.3561271e-05 [2.0042772] [1.9902773]
